# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./TopicModelling/mergedDF_after_TopicModelling.csv')

# %%
df
# Out:
#              product_Id  rating  \
# 0       B00001OPGT-0000       3
# 1       B00001OPGT-0001       4
# 2       B00001OPGT-0002       4
# 3       B00001OPGT-0003       5
# 4       B00001OPGT-0004       5
# ...                 ...     ...
# 324672  B00J5UD0FI-0000       3
# 324673  B00J5UD0FI-0001       4
# 324674  B00J5UD0FI-0002       4
# 324675  B00J5UD0FI-0003       5
# 324676  B00J5UD0FI-0004       5
#
#                                                   reviews  stopwords  \
# 0       case nice plenty pocket stuff office thin lapt...         76
# 1       month toshiba laptop case strong thou side bag...         44
# 2       pic product justice real thing good black synt...         26
# 3       pavilion rrb thing laptop front pocket fit pow...         38
# 4       happy bag expectation satellite adjustable pad...         32
# ...                                                   ...        ...
# 324672  good machine decent quality good job corner ha...         19
# ...

# %%
dict_response = {
    'Positive': ['Thank you so much for your feedback for',
                'Looking forward to hear more about terms ',
                'Hope you enjoyed terms on',
                'I am glad you liked terms '],
    'Negative': ['Apologies for the experience. Sorry about the matters on',
                'Can you please share how we can improve your experience of matters on',
                'Please reach out to complaints for matters on',
                'Can we offer you a replacement? Please contact our customer service for matters on']
}

# %%
for idx in range(0, len(df['topics'])):
    df['topics'][idx] = df['topics'][idx].split()[:4]
    df['topics'][idx]= ' '.join(df['topics'][idx])
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_68234/3577105427.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['topics'][idx] = df['topics'][idx].split()[:4]
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_68234/3577105427.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['topics'][idx]= ' '.join(df['topics'][idx])

# %%
from random import randint 
random_index = randint(0,3)

df['response']  = df.reviews
df.response[df.Sentiment == 0] =dict_response['Negative'][random_index] +" "+ df['topics'] + ". Thank you."
df.response[df.Sentiment == 1] = dict_response['Positive'][random_index] +" " + df['topics'] + ". Thank you."
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_68234/1410816492.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.response[df.Sentiment == 0] =dict_response['Negative'][random_index] +" "+ df['topics'] + ". Thank you."
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_68234/1410816492.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.response[df.Sentiment == 1] = dict_response['Positive'][random_index] +" " + df['topics'] + ". Thank you."

# %%
df['response'][1]
# Out:
# 'I am glad you liked terms  month toshiba laptop case. Thank you.'

# %%
df.to_csv('mergedDF_after_ResponseGeneration.csv', index=False)
