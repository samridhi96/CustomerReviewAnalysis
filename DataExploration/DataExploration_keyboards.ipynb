# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Preprocessing/keyboards_processed.csv')

# %%
df = df.iloc[: , 2:]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       2
# 1      B00000J1UG-0001       3
# 2      B00000J1UG-0002       3
# 3      B00000J1UG-0003       4
# 4      B00000J1UG-0004       4
# ...                ...     ...
# 33608  BT008UKTMW-0004       3
# 33609  BT008UKTMW-0005       3
# 33610  BT008UKTMW-0006       3
# 33611  BT008UKTMW-0007       4
# 33612  BT008UKTMW-0008       4
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [33613 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
from matplotlib.pyplot import figure

# %%
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# checking the reviews which are more than 750 stopwords
df[df['stopwords'] > 750]
# Out:
#             product_Id  rating  \
# 691    B0009B0H08-0028       2
# 2007   B000UC3EXI-0005       4
# 6786   B004MF11MU-0050       0
# 24826  B005EOWBKE-0037       2
# 29284  B00E1HIVG8-0010       1
# 33036  B008U5ZM6E-0053       3
# 33110  B008U5ZM6E-0127       4
#
#                                                  reviews  stopwords  \
# 691    many people computer family room next kitchen ...        755
# 2007   scorpius pro keyboard confusion review reserva...        825
# 6786   update purchase third party amazon month keybo...        909
# 24826  keyboard week update lag delay connectivity is...        759
# 29284  first keyboard great tactile key keyboard exce...        793
# 33036  lengthy review list pro detailed explanation p...        952
# 33110  bank cherry macro key side keyboard cherry bro...        823
#
#        punctuation  hastags  numerics  upper  word_count
# 691              0        0         0     68         360
# 2007             0        0         0     82         534
# 6786             0        0         0    119         439
# 24826            0        0         0    145         514
# 29284            0        0         0     83         501
# 33036            0        0         0    109         487
# 33110            0        0         0    109         665

# %%
# dropping the outliers which has more than 750 stopwords
df = df[df['stopwords'] < 750]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       2
# 1      B00000J1UG-0001       3
# 2      B00000J1UG-0002       3
# 3      B00000J1UG-0003       4
# 4      B00000J1UG-0004       4
# ...                ...     ...
# 33608  BT008UKTMW-0004       3
# 33609  BT008UKTMW-0005       3
# 33610  BT008UKTMW-0006       3
# 33611  BT008UKTMW-0007       4
# 33612  BT008UKTMW-0008       4
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [33606 rows x 9 columns]

# %%
# plot the stopwords curve in the reviews after removing the outliers
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# plot the punctuation curve in the reviews
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'red')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %%
# From the above graph, let check the puctuation 10-20 data
df[(df['punctuation'] >10) & (df['punctuation'] < 20)]
# Out:
#             product_Id  rating  \
# 3917   B002ORDWES-0003       2
# 4536   B00315W2K2-0002       0
# 4936   B003ELVLKU-0168       3
# 4966   B003ELVLKU-0198       3
# 5773   B003VAK16O-0065       4
# 6070   B003ZG9T62-0207       4
# 6636   B004JF9N1O-0042       3
# 7193   B004MF11MU-0457       4
# 10985  B007LQN8UU-0009       3
# 11248  B007X3VEC0-0009       0
# 11318  B007ZSV9XM-0030       0
# 13271  B00ALX0WAO-0001       2
# 13373  B00AZQ3966-0000       1
# 13625  B00BJVJV9A-0075       3
# 13651  B00BJVJV9A-0101       3
# 13800  B00BKW2410-0083       4
# 14141  B00CR6CEYK-0003       1
# 15742  B000A6PPOK-0089       4
# 16174  B000A6PPOK-0521       2
# 16276  B000A6PPOK-0623       4
# 16465  B000A6PPOK-0812       4
# 16809  B000CR1V5O-0032       3
# 17570  B000P6G6M0-0004       2
# 21077  B003SU7EQW-0007       3
# 22292  B00426HI8U-0000       0
# 24532  B005DLDTAE-0016       1
# 25601  B005L38VPC-0253       4
# 27459  B008PTTMGQ-0007       0
# 28295  B009TD83YY-0000       0
# 28713  B00BALK9CM-0096       3
# 29063  B00DR9V1T0-0009       1
# 29085  B00DR9V1T0-0031       2
# 29230  B00DWMPM92-0072       4
# 29373  B00E1HIVG8-0099       4
# 29385  B00E1HIVG8-0111       4
# 29446  B00E1HIVG8-0172       4
# 29609  B00EHBELXU-0002       3
# 29635  B00EU5WIDS-0002       1
# 29739  B00F9VPDJI-0025       4
# 29858  B00HMXIKCS-0009       3
# 29881  B00JKQSGWE-0002       4
# 32201  B005EOWBHC-0232       4
# 33072  B008U5ZM6E-0089       3
#
#                                                  reviews  stopwords  \
# 3917   keyboard washable anti microbial construction ...        227
# 4536   key product year problem disappointing item wo...         99
# 4936   mail far pro natural key well key comfortable ...         39
# 4966   light weight typical rubber dome technology st...        251
# 5773   bad large finger keyboard key small typo good ...         79
# 6070   keyboard good quality mechanical keyboard simi...        150
# 6636   case early people drawback keyboard cable shor...        243
# 7193   business environment day people type month fat...        246
# 10985  good keyboard use otg adapter cable hub mouse ...         79
# 11248  keyboard word garbage young daughter other key...        165
# 11318  ezeye regular amazon customer duty other probl...         66
# 13271  nice keyboard thing rrb involve setting langua...        313
# 13373  corsair cherry red part typical mechanical key...         87
# 13625  life upper left key keyboard home button home ...        112
# 13651  ipad mini smart cover excellent battery life c...        119
# 13800  anker slim wireless bluetooth keyboard third w...         76
# 14141  keyboard work io add front screen rrb type ent...         35
# 15742  use keyboard straight type cut type week menta...        106
# 16174  keyboard keyboard use work keyboard flat cheap...        132
# 16276  square keyboard board square board enough boar...         33
# 16465  natural keyboard pro keyboard hour day front c...        150
# 16809  solid construction extra key standard work fin...        191
# 17570  redone picture keyboard old version touchpad c...        596
# 21077  wireless keyboard year half work android table...        132
# 22292  keyboard description compatible user hooked ke...         56
# 24532  cordless keyboard battery keyboard little year...         27
# 25601  mini aluminum keyboard certain functionality t...         33
# 27459  idea keyboard new other well time keyboard imp...         36
# 28295  worth mechanical keyboard malfunction type pri...         86
# 28713  little screen keyboard touch interface conveni...        145
# 29063  pro unit keystroke excellent switch common sen...         82
# 29085  use htpc wall dive care good key great easy co...        211
# 29230  positive yep little keyboard saw much thing fo...         84
# 29373  reason several different reason first kindle f...        254
# 29385  seventh bluetooth keyboard work dell venue rrb...        190
# 29446  amazing question adapt use android cell phone ...         30
# 29609  overall comfortable bluetooth keyboard key exc...        129
# 29635  keyboard birthday gift moment much experience ...        131
# 29739  review sure touch keyboard slight nice click d...        277
# 29858  popular concept early due expensive rate cellu...        358
# 29881  number notable improvement last version keyboa...        284
# 32201  fantastic keyboard lightweight easy start keyb...        192
# 33072  keyboard reputation razor keyboard disappointe...         38
#
#        punctuation  hastags  numerics  upper  word_count
# 3917            12       12         0     21         148
# 4536            15       15         0     34          52
# 4936            11       11         0      2          26
# 4966            12       12         0     21         185
# 5773            12       12         0      9          57
# 6070            16       16         0     19          86
# 6636            11       11         0     95         146
# 7193            12       12         0     44         131
# 10985           12       12         0      6          57
# 11248           16       16         0     20         103
# 11318           14       14         0     30          56
# 13271           17       17         0     39         163
# 13373           14       14         0     16          50
# 13625           14       14         0     10          87
# 13651           12       12         0      5          77
# 13800           12       12         0      6          60
# 14141           17       17         0      3          22
# 15742           14       14         0     17          66
# 16174           12       12         0     23          81
# 16276           11       11         0      6          16
# 16465           12       12         0     20          97
# 16809           12       12         0     34         160
# 17570           12       12         0     51         352
# 21077           13       13         0     30         100
# 22292           14       14         0     17          50
# 24532           13       13         0      2          12
# 25601           11       11         0      3          38
# 27459           13       13         0      2          43
# 28295           12       12         0     17          44
# 28713           16       16         0     21          87
# 29063           14       14         0     13          64
# 29085           13       13         0     41         156
# 29230           12       12         0     10          41
# 29373           15       15         0     36         171
# 29385           16       16         0     40         153
# 29446           12       12         0      0          20
# 29609           16       16         0      9         100
# 29635           14       14         0     21          85
# 29739           16       16         0     34         169
# 29858           16       16         0     85         288
# 29881           18       18         0     38         238
# 32201           16       16         0     29         104
# 33072           11       11         0     20          22

# %%
# check the reviews
df[ df['punctuation'] > 20].reviews.tolist()
# Out:
# ['buyer beware update bank update price buck hour period buy price morning dollar rrb update mail item international version key big deal return buyer beware update replacement correct version product picture',
#  'satisfied performance job need user weight clunkiness keyboard mobile side power button attention power keyboard right shift key small time break unit lazy key alternative right choice long battery life durability lot research bluetooth keyboard perixx smart phone business communication content generation goal keyboard convenient key size productive speed small bag client short trip durable full time keyboard phone journal entry major document pamphlet book mobile device great battery life small footprint cross platform connectivity iphone nexus ipad mini factor broken stowaway idiot review size box keyboard heft sharp edge gaming peripheral company product addendum desktop gaming line german designer model soft corner light weight unwasted space norm successful product size sharp corner problem little effort cost round corner soft case bag ounce heavy user weight sturdy big battery fool physical size big time note measurement perixx market aluminum case review afraid key wife little heart rubber foot corner housing case short narrow sort unfair compare size keyboard smart phone keyboard massive surprising goal full size key able portable keyboard keyboard full sized key layout lot adaptation standard keyboard key comfortable good spacing key key dash bottom proper finger position dark keyboard space bar symmetrical small gap today review right side layout arrow pagination bottom slow locate right shift button key rds size fat finger arrow page key attention adhesive dot key locate touch right shift locate sacrifice generous size rest key usagethe control discovery button charge port edge housing side keyboard housing flat area battery radio home indicator light micro cable charge minute amber indicator green keyboard indicator keyboard reveal tiny magnet tiny peg hole accurate mating closing hinge simple durable keyboard housing unfolding mechanic elegant simple resistance complication open side side keyboard hinge stop degree parallel heft quality material perixx hinge side rigid parallel droop use keyboard flat surface top book notepad good idea portable keyboard note phone tablet obvious first week end host phone tablet standing thinking road stand figure way prop phone tablet tell thing work car bluetooth performance rock solid bluetooth radio problem apple blackberry window device host new host press discovery button side pin button toggle soft keyboard mobile device common barcode scanner keyboard time battery power phone tablet soft keyboard timeout key soft keyboard blackberry io battery life hour day day work day power quick standard micro extra cable nexus difficult turn power button small left side keyboard top button flush side little ridge difficult grip use tip finger nail move position impossible move pad finger short switch throw enough feedback success blue indicator light face keyboard light view button keyboard open flat table open bend half manipulate power button time imagine pressure top switch stop generous year warranty keyboard first week box middle key rrb required pressure other productivity killer superior build quality material problem design flaw assumption press key hard nope time lack responsiveness stiffness manufacturing key stubborness work',
#  'review user keyboard professional model much friendly keyboard rrb medium key hold operate use edit medium hassle control medium hard enough insane specific flaw da keyboard professional pro touch keyboard reason accurate mushy apple keyboard important accuracy coding keyboard less week medium control key pause volume mute great keyboard cable port keyboard rrb great port keyboard difference con window keyboard key key keyboard key key keyboard thing key reprogram dictation key system preference dictation speech dictation dictation key choice limited sign oversight numeric keypad number key hassle particular language syntax swap mess comment code key keyboard mac physical button optical drive real inconvenience people work mind key keyboard key keyboard big deal logo sign hunt peck typist key type aware keyboard user swap command option key system preference keyboard modifier key select keyboard swap function option command key desirable laptop keyboard contacted keyboard support option command key keyboard operating system update post hear',
#  'fuzzy product cold pricklie ergonomic usability ease average good bad fuzzie ratingdesign good fuzzie ratingconstruction quality bad fuzzie ratingperformance durability reliability terrible fuzzie ratingcompetitive pricing value bad fuzzie rating positive key nice smooth quiet action mushy keyboard handy calculator button negative nice action key space bar mushy key year moderate weekly use key comfortable ergonomic layout shape size error rate lsb key small feel year comfort curve keyboard retail store main work keyboard part keyboard ergonomic curvature key quiet spongy mushy moderate amount travel hate chiclet style keyboard common day ergonomic keyboard error ergonomic regular keyboards daily weekly basis main keyboard use work day accurate fast touch typist regular keyboard ergonomic keyboard error keyboard backspace reason right side pinky error key upper right lsb backspace rsb right strong pinky rrb experience key outer corner lsb rsb key rsb key small rounding lsb rsb key unnecessary fact ergonomic key bottom row key alt space bar rsb slope small lsb rsb key lsb space bar space bar mushy thumb mention wrist pad try keyboard wrist pad space bar solid lsb rsb key small difficult press wrist pad keyboard keyboard wrist rest hindsight purchase keyboard themicrosoft comfort curve keyboard sizing positioning key full size lsb alt rsb key well space bar design model model prone key main reason rate keyboard star month year moderate usage keyboard key key minute key lsb rsb keyboard useless failure single key render keyboard useless many user defective key comfort curve keyboard fuzzy keyboard model comfort curve keyboard model prone various key retrospect keyboard price high disposable keyboard year lifespan layout design ergonomic issue time much keyboard use year keyboard year hunk plastic garbage keyboard year year fine keyboard inexpensive last year moderate use year keyboard abuse liquid spill bypass keyboard curve keyboard model money reliable key switch keyboard model inherent design flaw quality issue well reliable keyboard less model',
#  'keyboard reviewer loud clacky hard push spacebar spacebar clicking noise loud review room order silliest thing right hand spacebar sound loud sound pen pencil desk book hand spacebar sound different sound sound left hand spacebar fleshy part finger desk spacebar center sound left hand single spacebar problem hand type fast word minute accuracy difficulty key spacebar short finger average size hand average size finger perfect standard keyboard puppy cup tea previous split keyboard time husband hook standard keyboard computer tea keyboard kind strange thing hit letter key weird thing wrong letter symbol triangle puppy lap tea keyboard lol general keyboard wonderful need split keyboard stand split style order standard keyboard poor review split style sense sound keyboard keyboard loud sound spacebar defect see issue review issue push spacebar key keyboard least key spacebar easy push stick necessary strike key thing keyboard multitude position instruction clear easy understand extra lift keyboard front keyboard palm high finger uncomfortable position use lift keyboard flat little leg back keyboard high front comfortable keyboard perfect position available trust split keyboard perfect perfect perfect love',
#  'book use hard productive numeric keypad wireless alternative deal battery prime full review quirk efficient keypad build quality entry level keyboard durable number rrb solid plastic construction keyboard ship free bottom line solid key response personal user key keyboard key subtle feedback feedback response close chiclet keyboard key light subtle click key response reference lsb mechanical key threshold audible click feedback touch response feedback key key order refresh key rsb press thick springboard key hit board release finger work time functional rrb white number num lock green key map white number white key access key triple rrb backspace good button key number mistake hand key mathematical function red number lsb num lock rsb key map red number red key access copy paste key nice zoom zoom tricky lsb rsb key use trigger home end right key great excel cell rrb sign weird white pro indicator numkey wonderful rrb key multifunction plug play driver installation case small compact optional function key support rrb good price number key multifunction con foam foot bottom basic foam foot key move much personal taste little elevation keypad personal thing music track lot functionality dfinal thought other good keypad support excel functionality great addition ultrabook good basic programming key thing macro support orbweaver numkey replacement right hand key number rrb side num key functional synapse reprogram naga easy need switch profile sub key',
#  'problem moment package fair defective unit due design htpc touchpad button mouse touchpad key touchpad functionality return multiple time rrb scrolling web page button many time key press press many many time scroll light bright night button tight uncomfortable push bluetooth button next keyboard backlight button silly dark keyboard exact position backlight button bluetooth button accident many many time opinion poor design backlight button identifiable reachable risk button dark press turn backlight button button easy small hole button pen press button key finger difficult find wrong key look keyboard mini keyboard different bluetooth dongle device sure late bluetooth driver defective unit resolve issue undecided replacement device different button next backlight button large enough issue replacement star defective unit worth star due design choice amount frustration time device several time half star',
#  'opinion junk logitech keyboard way delete home end page page button huge drawback least option press key missing button microscopic arrow key text thing keyboard right key feel sound placement medium button key dedicated volume key find night keyboard use htpc keyboard lap time keyboard awkward much bezel key trackpad edge keyboard battery top heavy keyboard sturdy plastic flex bend weight corner trackpad plate snap pick keyboard bottom right corner keyboard aluminum prevent trackpad bad defective click feedback half time hard registered find click clicking pad laptop trackpad dislike piece trackpad trackpad discreet right mouse button left clicking segregation keyboard difficult decent htpc keyboard peripheral company well bad apple product right first attempt money well',
#  'wireless bluetooth convenient work play iwerkz iwerkz universal foldable bluetooth keyboard portable keyboard people content iwerkz universal foldable bluetooth keyboard micro cable case device micro cable carrying case color micro carrying case choice checkout micro cable carrying case purple bluetooth keyboard micro interface common interface android mobile device today case tab slide inch tablet phone small clip heavy tablet phone good idea able fit nexus case tablet breaking micro cable well specification technology design convenient carry rechargeable lithium battery sustainable working time hour time day time hour foot micro interface protective cover double energy saver mode keyboard light ounce thin inch inch closed device bright color white blue black red pink purple stylish open keyboard magnetic resistance resistance switch button qwerty keyboard big difference bluetooth keyboard keyboard fact iwerkz key rrb key rrb key key android window io full functionality multimedia key key shift several manufacturer bluetooth keyboard versatile iwerkz suit overall construction keyboard innovative setupcharging plug micro cable keyboard end cable computer adapter rrb keyboard hour sure device capability slide power switch iwerkz keyboard position blue status light flash second press button iwerkz keyboard blue status setting screen iphone ipad android bluetooth device bluetooth keyboard screen type passkey key keyboard press complete testingas qwerty keyboard key awkward key use hand key large space set key minor issue key hand key letter classroom useful device media key rrb easy switch medium key limitation keyboard entire review keyboard long wrist key comfortable build key overall keyboard satisfied result final thoughtsi keyboard accurate keystroke comfortable entire review keyboard awkward key great keyboard product student keyboard small space product star fair price item pro comfortable small keyboard functionality key due size keyboard key sample exchange thorough honest review',
#  'keyboard bulky several wire keyboard sharkk backlit keyboard wireless bluetooth light wireless package content sharkk backlit keyboard wireless bluetooth carrying case cable user device inch micro usb cable common cable android device today accessible department store sharkk proprietary product case keyboard cable carrying case necessary convenience keyboard dust dirt specification interface standard operating distance foot modulation system gfsk operation voltage current standby current current current standby time day time hour lithium battery capacity working time day lithium battery life lithium battery spec key strength key life stroke temperature backlight open current backlight open standby time day keyboard razor thin small conventional keyboard rrb light qwerty standard black key keyboard keyboard option backlit color bright green soft blue deep blue red soft purple turquoise green brightness light bulb icon moment rrb color light bulb arrow arrow key keyboard small several key multifunctional curtsey key profile android window io keyboard good functionality plastic battery pack elevate keyboard button connect led battery one keyboard function overall keyboard rechargeable battery wire keyboard press connect button underside keyboard device connect button blue keyboard status indicator light complete status indicator light turn mobile device scan bluetooth device complete keyboard screen sahrkk keyboard select option input code keyboard press complete quality overall keyboard nice key bright key black color red bright soft purple soft blue deep blue key feedback overall nice issue connectivity hour finger half writing review problem key connectivitythe pairing process multiple device note nexus rrb optimus function well desktop write review keyboard lap half way keyboard second time top desk comment due external bluetooth adapter keyboard weak connection issue keyboard function foot uncomfortable bluetooth attempt convenience experience convenient final thoughtsi unpleasant experience keyboard desktop issue connectivity star incident likely experience experience device thin portable device luxurious price tag key feedback perfect internal battery several backlit option option bright other con testing keyboard connectivity issue desktop android phone tablet sample exchange thorough honest review',
#  'problem remote little research remote mass foreign company beware product form surface awesome little keyboard remote control remote button top remote control mouse flip recognize mouse turn keyboard wireless dependant line sight small fit hand good size neat concept wireless small donglemy implementation device xbmc raspberry keyboard navigation device work frustration motion mouse neat frustrating screen mouse lock button short period time able figure unlock button lock mouse place navigation button able lock mouse attempt navigation button button many click stuck constant key press confusing remote satisfying button button button pressed frustration inconsistency con intrusive consistent button registerbottom line work package email seller run problem contact bad review red flag point important beware product other identical']

# %%
df= df.drop_duplicates(subset=['reviews'])

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       2
# 1      B00000J1UG-0001       3
# 2      B00000J1UG-0002       3
# 3      B00000J1UG-0003       4
# 4      B00000J1UG-0004       4
# ...                ...     ...
# 33608  BT008UKTMW-0004       3
# 33609  BT008UKTMW-0005       3
# 33610  BT008UKTMW-0006       3
# 33611  BT008UKTMW-0007       4
# 33612  BT008UKTMW-0008       4
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [33597 rows x 9 columns]

# %% [markdown]
# there were 9 duplicates got dropped

# %%
# Lets review the data where punctuation is between 20-100
df[(df['punctuation'] >20) & (df['punctuation'] < 100)]
# Out:
#             product_Id  rating  \
# 7265   B004MF11MU-0529       4
# 13990  B00BU4OV50-0027       3
# 14931  B00JI2APZQ-0001       2
# 15447  B0009ZBRS0-0046       1
# 16045  B000A6PPOK-0392       4
# 27136  B007XCVFV6-0006       4
# 28627  B00BALK9CM-0010       0
# 29069  B00DR9V1T0-0015       1
# 29246  B00DWMPM92-0088       4
# 29340  B00E1HIVG8-0066       3
# 29680  B00EZL1IQA-0000       0
#
#                                                  reviews  stopwords  \
# 7265   buyer beware update bank update price buck hou...         67
# 13990  satisfied performance job need user weight clu...        701
# 14931  review user keyboard professional model much f...        271
# 15447  fuzzy product cold pricklie ergonomic usabilit...        324
# 16045  keyboard reviewer loud clacky hard push spaceb...        340
# 27136  book use hard productive numeric keypad wirele...        233
# 28627  problem moment package fair defective unit due...        234
# 29069  opinion junk logitech keyboard way delete home...        230
# 29246  wireless bluetooth convenient work play iwerkz...        325
# 29340  keyboard bulky several wire keyboard sharkk ba...        303
# 29680  problem remote little research remote mass for...        257
#
#        punctuation  hastags  numerics  upper  word_count
# 7265            52        2         0     17          31
# 13990           22       22         0     76         478
# 14931           21       21         0     30         153
# 15447           24       24         0     70         312
# 16045           22       22         0     55         179
# 27136           26       26         0    100         227
# 28627           22       22         0     39         131
# 29069           22       22         0     21         115
# 29246           65       65         0     59         285
# 29340           52       52         0     46         319
# 29680           23       23         0     27         116

# %%
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'blue')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %% [markdown]
# we have seen that the last two are dulplicates but it didnt got dropped, let drop it.

# %%
df = df[df['punctuation'] < 40]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       2
# 1      B00000J1UG-0001       3
# 2      B00000J1UG-0002       3
# 3      B00000J1UG-0003       4
# 4      B00000J1UG-0004       4
# ...                ...     ...
# 33608  BT008UKTMW-0004       3
# 33609  BT008UKTMW-0005       3
# 33610  BT008UKTMW-0006       3
# 33611  BT008UKTMW-0007       4
# 33612  BT008UKTMW-0008       4
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [33594 rows x 9 columns]

# %%
# Plotting the hastags 

df.hastags.value_counts().plot(kind= 'bar')
figure(dpi= 130)

# %%
df[df['hastags'] < 1]
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       2
# 1      B00000J1UG-0001       3
# 2      B00000J1UG-0002       3
# 3      B00000J1UG-0003       4
# 4      B00000J1UG-0004       4
# ...                ...     ...
# 33608  BT008UKTMW-0004       3
# 33609  BT008UKTMW-0005       3
# 33610  BT008UKTMW-0006       3
# 33611  BT008UKTMW-0007       4
# 33612  BT008UKTMW-0008       4
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [31278 rows x 9 columns]

# %% [markdown]
# Not many hashtags to consider here, we can ignore it for now

# %%
# Plotting the numerics

df.numerics.value_counts().plot(kind= 'bar', color= 'orange')
figure(figsize= (20,10))

# %%
# Plotting the 'upper' feature
figure(dpi= 120)
sns.kdeplot(df.upper, shade=True, cut=0)
sns.rugplot(df.upper);

# %%
df.loc[df.upper >=150].reviews.tolist()
# Out:
# ['prefacewhen old standard dell keyboard choice rating cyborg logitech several site use window bit system gamer extensive user productivity software developer sophisticated macro office product photoshop corel audio editing software web programming touch typist slouch lot understand recommendation perspective recommendation opinion sturdy high quality board many cyborg equivalent need work need lcd panel useful bit fragile impressed logitech equipment top line satisfied non gaming board durable star rating poor documentation navigation website confusing reviewer support problem case many installation programming bit sophisticated hard difficult need line manual software installation easy less time specification quality construction excellent rrb cyborg extruded plastic material keyboard key aluminum extra wear key laser system requirement window bit vistadimension hconnection microphone audio port connector computer keyboard design gaming white green red dark red blueillumination level medium bright intense spec new model bright number standard layout keypad yesinternet programmable key cyborg key physical possible shiftstate unshifted shift third shiftstate key ctrl state shiftervirtual key state key third shiftstate shifter rrb program code sst smart technology wireless nowarranty term part labor yearsconsideration simple likely issue time note easy advice keyboard port board port use net use port version computer rrb logitech slow rrb keyboard wide rrb standard physical space key bit small standard key problem key quiet silent advice key new model different feature reviewer software easy use new programming help manual type software keyboard driver rrb programming software optional program key rrb programming key little knowledge macro key command programmable key program hotkey many case advice advice problem keyboard least window pro bit operating platform rsb process day check legitimate mail address activation code porn spamming problem rrb registration free forum download driver software lsb beta rsb rsb future installation keyboard install software user manual new keyboard well user manual different keyboard rrb section lsb rsb smart technology guide plan program key lsb rsb keyboard software disable power management lsb rsb post solution administrator right driver software install manual rrb installation guide driver magic mouse software program key installation choice rrb new beta rrb version software driver keyboard keyboard port adapter keyboard power port operate program command hotkey manager manager rsb simple use rrb key quiet install utility sound noisy keyboard freeware lsb rsb lap remove wrist pad response protective clear plastic touchpad key manual slippery key finger key shoddy workmanship quality control rrb issue customer key hardware issue blue white light mine white breaker hue illumination bright bright white light amber dark red intense mean rrb dark color intensity key wear several different place key plastic wear letter regular key reviewer key response difficulty rrb programmable key possible function physical key function keyboard wrist pad know gap wrist pad problem old way rrb cord short standard size cord extension problem pricy market price competitor front update original purchase computer window bit machine keyboard day problem daughter bit computer flawless installation wrong keyboard',
#  'keyboard colorful different color combination key look cool light show effect personal opinion choose describe comment sleep mode review people sleep mode restart keyboard light order help keyboard certain color chioce color default color awake keyboard default color keyboard effect regular keyboard light instruction specific color set light show pick color pick daily default color matter keyboard sleep mode keyborad shut help thinking keyboard defective keyboard sleep mode awake keyboard light keyboard hope',
#  'ultimate inscription key cherry blue mechanism rrb electronics full key rollover blue mechanism rrb mechanical switch high speed hub iphone new rsb cherry blue mechanism rrb keyboard professional silent rrb silent model silent clicky rrb ideal people open environment worker type phone use brown mechanism imho typewriter serious thought keyboard effort detail operation adjustable uniform key touch spherical keycap ability multiple key hallmark feedback improved speed skill level competent typist next decade work typewriter frenzy cheap flat undersized plastic paddle flimsy mushy contact possible wrench eye hand coordination norm professional typing skill high school typing class way dodo german cherry brown clicky rrb preferred purpose key mechanism first comment reference cherry brown professional silent keyboard compact cherry majestouch action yellow key fkbn orfilco majestouch action metallic pink usa keyboard silent razerzone com keyboard good reputation low price rrb smooth feather touch key cylindrical keycap flat quality end chance key press extra key press rrb standard solid precise mouse keyboard short cord long problem primary motivation wireless headset connection key help key dark separate wrist pad gel wrist mechanical keyboard impressive big change rrb good tilt keyboard old typewriter keyboard pressure wrist wrist place front eye level low hand key combination low enough arm point downward type finger low wrist wrist pad rrb chair lumbar support brief stretching break minute wear lettering long time rrb hand moisturizer filco key cap problem lazer key quality legendary filco imho distribution rrb razer advantage inexpensive pulsing ultimate extra key macro software mouse legendary new razer silent popular gaming enthusiast available razer higer price update razerzone com function key razer right normal layout large key esp space bar high end keyboard variable key touch switch characteristic primary use well way rrb end basic type key switch good gaming hard press cherry black hand key easy cherry red rrb smooth travel switch good gaming cherry brown smooth light touch fast control typist gamer possible hard press gamer limited production cherry clear light switch halfway feel bump light clicky switch good lone typist noisy gamer cherry blue spring rrb bic pen click bumpafter preferred key characteristic key mechanical gaming keyboard professional keyboard action keyboard buckling spring classicibm ultimate silent mechanical gaming keyboard high speed key black rrb storm compact cherry white filco majestouch nkr action fkbn filco majestouch action metallic pink usa keyboard fkbn white elitekeyboard rare white deckkeyboard com legend rosewill rare filco majestouch cherry red fkbn black filco majestouch fkbn steelserie gaming keyboardfor build issue da keycap ab high durability resistance type dye pbt topre quiet mechanical electrostatic people slickness ab keycap pbt textured feel other difference difference great individual thing important example hand lotion rrb pbt deform production much ab long key spacebar many end big deal prone test keycap ab pbt sink rrb keycap due wear different custom ab lsb rsb lsb rsb use cherry key switch cheap comparable online review rrb people impossibility finding keyboard reason love amazon return policy well',
#  'delivery minute time keyboard wife laptop satelitte great work good riginal keyboard original drink spill yur laptop repair shop charge ton money minute local shop new laptop joke product less shipping happy great service quick delivery product state kudo lotfancy amazon great product great price sure laptop list sure work keyboard alot review people wrong feeling laptop homework doubt seller return headache',
#  'typist keyboard good mechanical keyboard considerable time mechanical keyboard satisfied criterion keyboard month initial star rating pro full size key mechanical switch mechanical spending keyboard shortcut rubber dome switch full size key mechanical keyboard mechanical key switch high price expense worth cost rrb dedicated medial control key volume control rrb important feature use volume website auto play video blaring volume gaming need adjust volume distraction mechanical keyboard combination keystroke key key short rrb media control dedicated key well good imo fact major reason keyboard other rrb gaming macro key useful game multiple row bank easy key game software game bank image program bank lighting key key medium key bright high level brightness bright rrb option fyi way key cap mechanical key post top key illuminate example key numpad number product design flaw concession cherry mechanical switch rrb cherry brown key switch hard core gamer type bit mechanical switch good well able test prior purchase hybrid switch brown switch safe choice actuation force red switch inaudible soft noticeable bump extended use cherry brown switch excellent good gaming rrb key rollover ability least key rollover ability rrb sound dampening ring switch silent level volume reasonable level certain price good attention detail excellent build quality flawless condition scratch problem solid strong metal frame non mechanical key nice solid feeling cherry mechanical switch last keystroke confident keyboard last year layout key control compact crowded design well overall layout close wrong key control user complaint key close key least full key width space present similar keyboard corsair esc mistake con rrb marking top row number key top top true dual function key mark period key reason way lighting work cherry switch logitech position non shift symbol backlight shift function fair standard marking bad case scenario bother enough key cap big complaint orange border key color garish decision color unfathomable bother much thought warranty black connection keyboard port able connection panel free port mechanical gaming keyboard key rollover port cable keyboard port front panel port sufficient cable connection detachable well rrb mechanical switch key rubber keyboard fault fact surprised easy dust dirt keycap dust bad clear compressed air large keycap snack friendly keyboard high mechanical keyboard cheap ring prong mechanical keyboard amazon electronic utf qid spell couple dollar cheap type worth extra money easy less risk damage level keycap palm wrist rest worthless non ergonomic wrist parallel cheap default con plan month keyboard lot star rating perfect rrb pro con logitech interested mechanical keyboard non gamer brown switch linear mechanical switch cherry red black switch corsair similar term layout cherry red brown switch',
#  'nice keyboard star rating many subtle flaw major mind flaw star rating amazon half star rating detailed breakdown review rrb lsb rsb first thing keyboard natural ergonomic keyboard several wave keyboard keyboard spite fact ergonomic bit adjustment finger placement big deal key chiclet candy plastic plunger high quality right amount feedback laptop keyboard apple desktop keyboard feel hard surface key plunger springy feel firm mini key wonderful typing experience key good kinda leave key little bit key typical qwerty configuration backspace cap button small keyboard bad thing row key close number row key keyboard bad thing imho rrb keyboard flat rrb user little rubber foot bottom extended tilt keyboard rrb user great typing experience wish ergonomic key rrb backlight lsb rsb illumination feature foremost selling point particular keyboard particular price point logitech good armr keyboard sensitive body heat arm armr keyboard register nice touch backlight keyboard use light key lot solid opaque plastic letter top letter key translucent individual backlight letter number key key jet black rrb backlight brightness setting addition use keyboard non illuminated keyboard high rrb bright second sufficient time uniform level keyboard whole logitech nice job brightness setting addition novel heat armr feature rrb material lsb rsb key opaque black color letter color novel way key keyboard letter key board keyboard new manufacturing process body keyboard hard high quality plastic armr nice padded feel keyboard rubber foot bottom prevent keyboard body thin clear plastic border complement plastic look letter key keyboard sophisticated beef major keyboard trip luggage shocked find clip thing individual key rrb key broken clip fragile logitech replace clip sale certain online auction site couple buck rrb cat keyboard think fragility keyboard clip key keyboard body super durable clip little bit iffy certain circumstance rrb battery life lsb rsb keyboard least sanyo eneloop battery rrb swear battery electronic device access battery compartment single phillip head keyboard battery eneloop keyboard rate eneloop good rechargeable battery consumer market imho kudo logitech premium product auto turn feature backlight second non usage battery life physical switch computer couple hour battery life brightness setting backlight high setting battery charge hour usage second third setting hour usage battery single charge plug keyboard port use nice touch logitech keyboard backlight shut critical battery level rrb keyboard regular non illuminated keyboard hour hour critical level keyboard function little power feature particular keyboard bar battery life indicator check time beef feature show solid bar indicator unplug green bar green bar green bar hour backlight turn red bar critical battery level bar battery indicator full empty battery critical charge cycle complete guess usage work lot well little disappointed feature rrb software wireless lsb rsb odd first communicate computer logitech receiver tiny fingernail laptop computer tower time great keyboard receiver several different peripheral mouse receiver run keyboard performance mouse receiver handy people limited number port mouse keyboard time problem range keyboard foot receiver logitech great software disable key insert key cap key customize key function disable heat armr backlight feature software keep keyboard rrb time happy software small translucent screen screen second turn cap num lock scroll lock battery critical keyboard change volume computer feature lot disabled software rrb total score star']

# %%
df = df[df['upper'] < 300]

# %%
# Check the rating graph with the number of reviews
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df['rating'] = df['rating'].apply(lambda x: x + 1)
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3440/2078441892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].apply(lambda x: x + 1)

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       3
# 1      B00000J1UG-0001       4
# 2      B00000J1UG-0002       4
# 3      B00000J1UG-0003       5
# 4      B00000J1UG-0004       5
# ...                ...     ...
# 33608  BT008UKTMW-0004       4
# 33609  BT008UKTMW-0005       4
# 33610  BT008UKTMW-0006       4
# 33611  BT008UKTMW-0007       5
# 33612  BT008UKTMW-0008       5
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      2          14
# 1                0        0         0     14          42
# 2                0        0         0     22         103
# 3                0        0         0      0          14
# 4                0        0         0      2          13
# ...            ...      ...       ...    ...         ...
# 33608            0        0         0      1          14
# 33609            0        0         0      4          20
# 33610            0        0         0      7          26
# 33611            0        0         0      6          22
# 33612            0        0         0      1          15
#
# [33593 rows x 9 columns]

# %%
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %% [markdown]
# Mapped the values 0,1,2,3,4 to 1-5 of ratings. As we can see that most of the reviews has 4/5 ratings as compared to 1/2/3

# %% [markdown]
# lets consider ratings with 4 and 5 as good and 1,2 and 3 as bad review

# %%
df['Review_type']= df.rating
df.Review_type[df.rating <= 3] = 0 #bad review
df.Review_type[df.rating >= 4] = 1 #good review
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3440/3456672084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review_type']= df.rating
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3440/3456672084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating <= 3] = 0 #bad review
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3440/3456672084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating >= 4] = 1 #good review

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       3
# 1      B00000J1UG-0001       4
# 2      B00000J1UG-0002       4
# 3      B00000J1UG-0003       5
# 4      B00000J1UG-0004       5
# ...                ...     ...
# 33608  BT008UKTMW-0004       4
# 33609  BT008UKTMW-0005       4
# 33610  BT008UKTMW-0006       4
# 33611  BT008UKTMW-0007       5
# 33612  BT008UKTMW-0008       5
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33608  great little device price other market keyboar...         24
# 33609  product least part rrb easy install keyboard p...         19
# 33610  drawer installation template drawer essential ...         39
# 33611  old oak desk father office new furniture desk ...         42
# 33612  sturdy extra space desk top keyboard desk top ...         21
#
#        punctuation  hastags  numerics  upper  word_count  Review_type
# 0                0        0         0      2          14            0
# 1                0        0         0     14          42            1
# 2                0        0         0     22         103            1
# 3                0        0         0      0          14            1
# 4                0        0         0      2          13            1
# ...            ...      ...       ...    ...         ...          ...
# 33608            0        0         0      1          14            1
# 33609            0        0         0      4          20            1
# 33610            0        0         0      7          26            1
# 33611            0        0         0      6          22            1
# 33612            0        0         0      1          15            1
#
# [33593 rows x 10 columns]

# %%
df.Review_type.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df.to_csv('keyboards_after_data_exploration.csv', index=False)
