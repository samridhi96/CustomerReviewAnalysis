# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Preprocessing/boots_processed.csv')

# %%
df = df.iloc[: , 2:]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       0
# 1      B0000DFAXV-0001       0
# 2      B0000DFAXV-0002       0
# 3      B0000DFAXV-0003       3
# 4      B0000DFAXV-0004       3
# ...                ...     ...
# 77488  B00HD65LD0-0000       1
# 77489  B00HD65LD0-0001       2
# 77490  B00HD65LD0-0002       3
# 77491  B00HD65LD0-0003       4
# 77492  B00HD65LD0-0004       4
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 1                1        1         0      2          19
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# ...            ...      ...       ...    ...         ...
# 77488            0        0         0      4          28
# 77489            2        2         0      2          23
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [77493 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
from matplotlib.pyplot import figure

# %%
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# checking the reviews which are more than 400 stopwords
df[df['stopwords'] > 400]
# Out:
# Empty DataFrame
# Columns: [product_Id, rating, reviews, stopwords, punctuation, hastags, numerics, upper, word_count]
# Index: []

# %%
# dropping the outliers which has more than 400 stopwords
df = df[df['stopwords'] < 400]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       0
# 1      B0000DFAXV-0001       0
# 2      B0000DFAXV-0002       0
# 3      B0000DFAXV-0003       3
# 4      B0000DFAXV-0004       3
# ...                ...     ...
# 77488  B00HD65LD0-0000       1
# 77489  B00HD65LD0-0001       2
# 77490  B00HD65LD0-0002       3
# 77491  B00HD65LD0-0003       4
# 77492  B00HD65LD0-0004       4
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 1                1        1         0      2          19
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# ...            ...      ...       ...    ...         ...
# 77488            0        0         0      4          28
# 77489            2        2         0      2          23
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [77485 rows x 9 columns]

# %%
# plot the stopwords curve in the reviews after removing the outliers
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# plot the punctuation curve in the reviews
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'red')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %%
# From the above graph, let check the puctuation 10-20 data
df[(df['punctuation'] >25) ]
# Out:
#             product_Id  rating reviews  stopwords  punctuation  hastags  \
# 50987  B004M105AI-0002       4    ecco          0          177      177
#
#        numerics  upper  word_count
# 50987         0      1           1

# %%
# check the reviews
df[ df['punctuation'] > 25].reviews.tolist()
# Out:
# ['ecco']

# %%
df= df.drop_duplicates(subset=['reviews'])

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       0
# 1      B0000DFAXV-0001       0
# 2      B0000DFAXV-0002       0
# 3      B0000DFAXV-0003       3
# 4      B0000DFAXV-0004       3
# ...                ...     ...
# 77488  B00HD65LD0-0000       1
# 77489  B00HD65LD0-0001       2
# 77490  B00HD65LD0-0002       3
# 77491  B00HD65LD0-0003       4
# 77492  B00HD65LD0-0004       4
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 1                1        1         0      2          19
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# ...            ...      ...       ...    ...         ...
# 77488            0        0         0      4          28
# 77489            2        2         0      2          23
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [77478 rows x 9 columns]

# %% [markdown]
# there were 7 duplicates got dropped

# %%
# Lets review the data where punctuation is between 20-25
df[(df['punctuation'] >20) & (df['punctuation'] < 25)]
# Out:
#             product_Id  rating  \
# 9477   B007CGWSS2-0000       0
# 74178  B00D3A67MO-0091       4
#
#                                                  reviews  stopwords  \
# 9477   call leather description point actuality mater...         88
# 74178  heart legit chuck knee money shoe fraction pri...        289
#
#        punctuation  hastags  numerics  upper  word_count
# 9477            22       22         0     11          82
# 74178           21       21         0     48         135

# %%
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'blue')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %% [markdown]
# There is an outlier, lets drop it

# %%
df = df[df['punctuation'] < 25]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       0
# 1      B0000DFAXV-0001       0
# 2      B0000DFAXV-0002       0
# 3      B0000DFAXV-0003       3
# 4      B0000DFAXV-0004       3
# ...                ...     ...
# 77488  B00HD65LD0-0000       1
# 77489  B00HD65LD0-0001       2
# 77490  B00HD65LD0-0002       3
# 77491  B00HD65LD0-0003       4
# 77492  B00HD65LD0-0004       4
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 1                1        1         0      2          19
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# ...            ...      ...       ...    ...         ...
# 77488            0        0         0      4          28
# 77489            2        2         0      2          23
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [77477 rows x 9 columns]

# %%
# Plotting the hastags 

df.hastags.value_counts().plot(kind= 'bar')
figure(dpi= 130)

# %%
df[df['hastags'] < 1]
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       0
# 2      B0000DFAXV-0002       0
# 3      B0000DFAXV-0003       3
# 4      B0000DFAXV-0004       3
# 5      B0000DFAXV-0005       3
# ...                ...     ...
# 77487  B00GZ6QWIM-0006       4
# 77488  B00HD65LD0-0000       1
# 77490  B00HD65LD0-0002       3
# 77491  B00HD65LD0-0003       4
# 77492  B00HD65LD0-0004       4
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# 5      star nice boot good quality half star shoe ton...         26
# ...                                                  ...        ...
# 77487    little big fit true size rest winter boot small          0
# 77488  shoe size large least mine strange many pair d...         35
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# 5                0        0         0      4          25
# ...            ...      ...       ...    ...         ...
# 77487            0        0         0     31           9
# 77488            0        0         0      4          28
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [73005 rows x 9 columns]

# %% [markdown]
# Not many hashtags to consider here, we can ignore it for now

# %%
# Plotting the numerics

df.numerics.value_counts().plot(kind= 'bar', color= 'orange')
figure(figsize= (20,10))

# %%
# Plotting the 'upper' feature
figure(dpi= 120)
sns.kdeplot(df.upper, shade=True, cut=0)
sns.rugplot(df.upper);

# %%
df.loc[df.upper >=150].reviews.tolist()
# Out:
# ['cute boot comfortable put unstable due height use high inch boot inch cork heel fit work shoe line work health department foot day shoe day long issue foot pain boot wear town comfy darn well luck bummer',
#  'boot different appearance leather seam rub top ankle annoying tie undone apparent reason unlaced pain tie knot minnetonka leather moccasin slouch bit size bit big wear minnetonka half size small order big size half size small',
#  'boot review small order size big true size order size toobig exchange review small ihad hard way mistake order size advice addition size instance fine sock size order size previous size fit wonderful thought day small happy purchase quality nice sooo comfortable mention tootsie warm matter weather water repellant plan wet weather suede wet',
#  'nice boot great support foot beautiful design quarm shiny boot thin leather thin leather bit obvious photo preview boot large bit elastic part great comfort fit alittle wear sure top calf elastic tight trouble zipping boot top time wear boot stretcher liquid help medium little large zip way swollen leg arthritis little stretch comfort double check top boot lady light leather material gorgeous boot easy boot stretch boot shoe man boot good happpy aussie',
#  'problem foot great pair warm boot lsb foot cold rsb warm stable foot price chance order sigh rsb great incredible boot lsb gon suede cleaner nice rsb perfect size lsb coul size toe top fur keep foot warm rsb fur soft incredible boot straight leg pant skirt great brown rich color design slouch boot fall bit bug happy boot long period foot lsb break hurt rsb foot happy amazon',
#  'boot day eager purchase boot box nice box pink satin ribbon excited nice pair boot site nice smooth leather touch patent leather top clear ground fushia pink sole top feminine touch class describe boot boot bad thing boot calf area boot much space available leg nice calf body calf area boot woman sizable calf boot true size shoe store tighten calf area boot rrb boot rate rrb calf area boot other thing heel high hand heel wearer fine love high heel boot customer happy struten stuff rrb',
#  'great cute little boot long boot fact long enough ankle boot short knee boot great little feeling casual wear jean classy cute dress love hug calf gap look loose problem hand bit stiff option top cuff flannel set side long cuff way great find love']

# %%
df = df[df['upper'] < 150]

# %%
# Check the rating graph with the number of reviews
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df['rating'] = df['rating'].apply(lambda x: x + 1)
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3681/2078441892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].apply(lambda x: x + 1)

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       1
# 1      B0000DFAXV-0001       1
# 2      B0000DFAXV-0002       1
# 3      B0000DFAXV-0003       4
# 4      B0000DFAXV-0004       4
# ...                ...     ...
# 77488  B00HD65LD0-0000       2
# 77489  B00HD65LD0-0001       3
# 77490  B00HD65LD0-0002       4
# 77491  B00HD65LD0-0003       5
# 77492  B00HD65LD0-0004       5
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      8          28
# 1                1        1         0      2          19
# 2                0        0         0      5          28
# 3                0        0         0      1           7
# 4                0        0         0     13          40
# ...            ...      ...       ...    ...         ...
# 77488            0        0         0      4          28
# 77489            2        2         0      2          23
# 77490            0        0         0     10          31
# 77491            0        0         0      2          17
# 77492            0        0         0      8          36
#
# [77470 rows x 9 columns]

# %%
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %% [markdown]
# Mapped the values 0,1,2,3,4 to 1-5 of ratings. As we can see that most of the reviews has 4/5 ratings as compared to 1/2/3

# %% [markdown]
# lets consider ratings with 4 and 5 as good and 1,2 and 3 as bad review

# %%
df['Review_type']= df.rating
df.Review_type[df.rating <= 3] = 0 #bad review
df.Review_type[df.rating >= 4] = 1 #good review
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3681/3456672084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review_type']= df.rating
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3681/3456672084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating <= 3] = 0 #bad review
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3681/3456672084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating >= 4] = 1 #good review

# %%
df
# Out:
#             product_Id  rating  \
# 0      B0000DFAXV-0000       1
# 1      B0000DFAXV-0001       1
# 2      B0000DFAXV-0002       1
# 3      B0000DFAXV-0003       4
# 4      B0000DFAXV-0004       4
# ...                ...     ...
# 77488  B00HD65LD0-0000       2
# 77489  B00HD65LD0-0001       3
# 77490  B00HD65LD0-0002       4
# 77491  B00HD65LD0-0003       5
# 77492  B00HD65LD0-0004       5
#
#                                                  reviews  stopwords  \
# 0      shoe favorite color timberland shoe disappoint...         66
# 1      seller wrong tracking package boot correct box...         41
# 2      company email item size size little week sever...         73
# 3                  great foot wide tight need nice color         14
# 4      boot picture quality tad big small narrow foot...         74
# ...                                                  ...        ...
# 77488  shoe size large least mine strange many pair d...         35
# 77489  wonderful fit nice look shoe terrible chemical...         29
# 77490  shoe first time today desk job walk lot day so...         50
# 77491  pink color spring shoe cute comfortable day se...         25
# 77492  amazon price shoe affordable half price gorgeo...         52
#
#        punctuation  hastags  numerics  upper  word_count  Review_type
# 0                0        0         0      8          28            0
# 1                1        1         0      2          19            0
# 2                0        0         0      5          28            0
# 3                0        0         0      1           7            1
# 4                0        0         0     13          40            1
# ...            ...      ...       ...    ...         ...          ...
# 77488            0        0         0      4          28            0
# 77489            2        2         0      2          23            0
# 77490            0        0         0     10          31            1
# 77491            0        0         0      2          17            1
# 77492            0        0         0      8          36            1
#
# [77470 rows x 10 columns]

# %%
df.Review_type.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df.to_csv('boots_after_data_exploration.csv', index=False)
