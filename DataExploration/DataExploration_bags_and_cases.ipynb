# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Preprocessing/bags_and_cases_processed.csv')

# %%
df = df.iloc[: , 2:]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42627  B00JO6UGFU-0004       4
# 42628  B00JO6UGFU-0005       4
# 42629  B00JO6UGFU-0006       4
# 42630  B00JO6UGFU-0007       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
from matplotlib.pyplot import figure

# %%
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# checking the reviews which are more than 600 stopwords
df[df['stopwords'] > 600]
# Out:
#             product_Id  rating  \
# 1639   B000NONHYY-0129       4
# 11707  B005HEUUEA-0042       4
# 12494  B0076D099Q-0011       2
# 15314  B00009R6TA-0199       3
# 20549  B002V92Z2O-0018       3
# 21210  B003LPUU3I-0018       4
# 22755  B004HXYDEU-0000       2
# 23719  B004VD7HQW-0018       3
# 25668  B0076D048C-0002       3
#
#                                                  reviews  stopwords  \
# 1639   preface review prior swiss gear synergy gear h...        693
# 11707  travel business easy functional bag thing impo...        675
# 12494  concept ogio thule ogio particular certain thi...        611
# 15314  march year backpack wear little low price ligh...        831
# 20549  timbuk new version bag new model swivel strap ...        615
# 21210  new rock top review manufacturer eye user revi...        705
# 22755  original review star lot time researching purc...        620
# 23719  mile round trip school commute bike bike bus g...        698
# ...

# %%
# dropping the outliers which has more than 600 stopwords
df = df[df['stopwords'] < 600]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42627  B00JO6UGFU-0004       4
# 42628  B00JO6UGFU-0005       4
# 42629  B00JO6UGFU-0006       4
# 42630  B00JO6UGFU-0007       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
# plot the stopwords curve in the reviews after removing the outliers
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# plot the punctuation curve in the reviews
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'red')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %%
# From the above graph, let check the puctuation 10-20 data
df[(df['punctuation'] >10) & (df['punctuation'] < 20)]
# Out:
#             product_Id  rating  \
# 11664  B005H4GO0E-0007       4
# 12208  B006P65OJ0-0000       2
# 12519  B0076D099Q-0036       4
# 13581  B00965FJ24-0003       4
# 22877  B004IVAPM0-0058       4
# 26868  B007X3VC7W-0068       4
# 27058  B0085B772A-0017       2
# 30602  B000EOGW9K-0027       4
# 39195  B007T8S490-0091       1
# 40282  B008DWCPP0-0002       3
# 40695  B00997NC7S-0014       4
# 42552  B00HSGFPC2-0006       4
#
#                                                  reviews  stopwords  \
# 11664  one craziness many pocket pocket pad laptop ea...        149
# 12208  review sized backpack backpack time couple wee...        161
# 12519  first website bag detail feature reason love b...        569
# 13581  summary bag briefcase seaching goldilock happy...        383
# 22877  love case end computer year easy wrist type ke...        209
# 26868  addiction bad word addiction equal instance lo...        307
# 27058  item case logic lap laptop macbook sleeve time...         66
# ...

# %%
# check the reviews
df[ df['punctuation'] > 20].reviews.tolist()
# Out:
# ['main issue people sleeve fit laptop macbook pro sleeve large product big sleeve macbook air spec difference sleeve macbook long macbook air sleeve dimension matter thickness rrb laptop macbook first snugness due thickness laptop mine thick battery side laptop thick large sleeve pair shoe little bit time huge amount estimate large laptop air sleeve accommodate thick macbook air version much extra space length macbook air version well seller long extra length big deal way laptop danger grip hand laptop drag laptop sleeve small timbuk messenger bag little bulk page magazine doubt laptop secure impact little knock many people product friendly little research case polyester material polyester clothing pet plastic common form plastic bottle rrb fact product rpet recycled plastic bottle plastic converted fiber well job environmental benefit recycled plastic virgin material petroleum friendly laptop sleeve many neoprene vulcanization accelerator foam formamide project non food grade neopre
# ...

# %% [markdown]
# We can see there are duplicate reviews in the range of punctuations from 10 to 40

# %%
df= df.drop_duplicates(subset=['reviews'])

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42627  B00JO6UGFU-0004       4
# 42628  B00JO6UGFU-0005       4
# 42629  B00JO6UGFU-0006       4
# 42630  B00JO6UGFU-0007       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %% [markdown]
# there were 5 duplicates got dropped

# %%
# Lets review the data where punctuation is between 10-20
df[(df['punctuation'] >10) & (df['punctuation'] < 20)]
# Out:
#             product_Id  rating  \
# 11664  B005H4GO0E-0007       4
# 12208  B006P65OJ0-0000       2
# 12519  B0076D099Q-0036       4
# 13581  B00965FJ24-0003       4
# 22877  B004IVAPM0-0058       4
# 26868  B007X3VC7W-0068       4
# 27058  B0085B772A-0017       2
# 30602  B000EOGW9K-0027       4
# 39195  B007T8S490-0091       1
# 40282  B008DWCPP0-0002       3
# 40695  B00997NC7S-0014       4
# 42552  B00HSGFPC2-0006       4
#
#                                                  reviews  stopwords  \
# 11664  one craziness many pocket pocket pad laptop ea...        149
# 12208  review sized backpack backpack time couple wee...        161
# 12519  first website bag detail feature reason love b...        569
# 13581  summary bag briefcase seaching goldilock happy...        383
# 22877  love case end computer year easy wrist type ke...        209
# 26868  addiction bad word addiction equal instance lo...        307
# 27058  item case logic lap laptop macbook sleeve time...         66
# ...

# %%
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'blue')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %% [markdown]
# we have seen that the last two are dulplicates but it didnt got dropped, let drop it.

# %%
df = df[df['punctuation'] < 40]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42627  B00JO6UGFU-0004       4
# 42628  B00JO6UGFU-0005       4
# 42629  B00JO6UGFU-0006       4
# 42630  B00JO6UGFU-0007       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
# Plotting the hastags 

df.hastags.value_counts().plot(kind= 'bar')
figure(dpi= 130)

# %%
df[df['hastags'] < 1]
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42624  B00JO6UGFU-0001       3
# 42625  B00JO6UGFU-0002       4
# 42626  B00JO6UGFU-0003       4
# 42628  B00JO6UGFU-0005       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42624  macbook air inch clear hard speck case fit har...         35
# ...

# %% [markdown]
# Not many hashtags to consider here, we can ignore it for now

# %%
# Plotting the numerics

df.numerics.value_counts().plot(kind= 'bar', color= 'orange')
figure(figsize= (20,10))

# %% [markdown]
# Nothing to be done on numerics

# %%
# Plotting the 'upper' feature
figure(dpi= 120)
sns.kdeplot(df.upper, shade=True, cut=0)
sns.rugplot(df.upper);

# %%
df.loc[df.upper >=100].reviews.tolist()
# Out:
# ['me informacion por atencion que espera deadline month item information least know item possible attention answer several time solution situation information thing item asap money information problem item possible answer fix situation bad news purchase think solution least money item',
# ...

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       2
# 1      B00001OPGT-0001       3
# 2      B00001OPGT-0002       3
# 3      B00001OPGT-0003       4
# 4      B00001OPGT-0004       4
# ...                ...     ...
# 42627  B00JO6UGFU-0004       4
# 42628  B00JO6UGFU-0005       4
# 42629  B00JO6UGFU-0006       4
# 42630  B00JO6UGFU-0007       4
# 42631  B00JO6UGFU-0008       4
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
# Check the rating graph with the number of reviews
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df['rating'] = df['rating'].apply(lambda x: x + 1)
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_42034/2078441892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].apply(lambda x: x + 1)

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       3
# 1      B00001OPGT-0001       4
# 2      B00001OPGT-0002       4
# 3      B00001OPGT-0003       5
# 4      B00001OPGT-0004       5
# ...                ...     ...
# 42627  B00JO6UGFU-0004       5
# 42628  B00JO6UGFU-0005       5
# 42629  B00JO6UGFU-0006       5
# 42630  B00JO6UGFU-0007       5
# 42631  B00JO6UGFU-0008       5
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %% [markdown]
# Mapped the values 0,1,2,3,4 to 1-5 of ratings. As we can see that most of the reviews has 4/5 ratings as compared to 1/2/3

# %% [markdown]
# lets consider ratings with 4 and 5 as good and 1,2 and 3 as bad review

# %%
df['Review_type']= df.rating
df.Review_type[df.rating <= 3] = 0 #bad review
df.Review_type[df.rating >= 4] = 1 #good review
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_42034/3456672084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review_type']= df.rating
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_42034/3456672084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating <= 3] = 0 #bad review
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       3
# 1      B00001OPGT-0001       4
# 2      B00001OPGT-0002       4
# 3      B00001OPGT-0003       5
# 4      B00001OPGT-0004       5
# ...                ...     ...
# 42627  B00JO6UGFU-0004       5
# 42628  B00JO6UGFU-0005       5
# 42629  B00JO6UGFU-0006       5
# 42630  B00JO6UGFU-0007       5
# 42631  B00JO6UGFU-0008       5
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 42627  great cheap fit macbook air perfect amount poc...         28
# ...

# %%
df.Review_type.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df.to_csv('bags_and_cases_after_data_exploration.csv', index=False)
