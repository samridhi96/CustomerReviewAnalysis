# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Preprocessing/bluetooth_processed.csv')

# %%
df = df.iloc[: , 2:]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80143  B00JFLAEO2-0001       1
# 80144  B00JFLAEO2-0002       1
# 80145  B00JFLAEO2-0003       2
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80148 rows x 9 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
from matplotlib.pyplot import figure

# %%
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# checking the reviews which are more than 750 stopwords
df[df['stopwords'] > 750]
# Out:
#             product_Id  rating  \
# 13514  B00DOP3NPW-0052       4
# 16968  B000RPT2QQ-0050       4
# 21761  B0052YQMLA-0102       4
# 57477  B00EDOADCO-0001       3
# 57697  B00FDXB7MO-0003       3
# 61374  B000VAPXBA-0032       3
#
#                                                  reviews  stopwords  \
# 13514  little background killer headphone new pair hi...        825
# 16968  disclaimer expert kind phone expert phone firs...        924
# 21761  thorough answer many question possible much mo...        752
# 57477  aleratec tunephonik bluetooth headphone iphone...        763
# 57697  new smartphone bluetooth stereo headphone adva...        771
# 61374  small flaw great product firmware edit charger...        786
#
#        punctuation  hastags  numerics  upper  word_count
# 13514            0        0         0     90         512
# 16968            0        0         0     60         514
# 21761            0        0         0     62         392
# 57477            6        6         0     77         387
# 57697            0        0         0     86         413
# 61374            0        0         0     92         567

# %%
# dropping the outliers which has more than 750 stopwords
df = df[df['stopwords'] < 750]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80143  B00JFLAEO2-0001       1
# 80144  B00JFLAEO2-0002       1
# 80145  B00JFLAEO2-0003       2
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80142 rows x 9 columns]

# %%
# plot the stopwords curve in the reviews after removing the outliers
figure(dpi= 120)
sns.distplot(df.stopwords, rug=True, hist=False, color = 'green')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='stopwords', ylabel='Density'>

# %%
# plot the punctuation curve in the reviews
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'red')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %%
# From the above graph, let check the puctuation 20-100 data
df[(df['punctuation'] >20) & (df['punctuation'] < 100)]
# Out:
#             product_Id  rating  \
# 7424   B004J96SB8-0025       4
# 13738  B00ENF5CZQ-0006       3
# 13987  B00HWT8I24-0014       3
# 14355  B00JLVNF2O-0024       4
# 26781  B00AVLOHJ8-0936       4
# 28487  B00DIOALPE-0023       0
# 29805  B00IBCRZ3Y-0052       4
# 33285  B001BOEOLK-0001       0
# 38085  B005FPT380-0005       0
# 43431  B00D2CRXKI-0067       2
# 43500  B00D2CRXKI-0136       4
# 44822  B00J5HDEPC-0035       3
# 45312  B0006HTZ80-0211       3
# 67636  B0052YFYFK-0141       3
# 73920  B00DDCHIM0-0001       0
# 74326  B00G6RIF2Q-0002       4
#
#                                                  reviews  stopwords  \
# 7424   year good insurance policy cell phone coverage...        502
# 13738  new bluetooth headset car opportunity headset ...        260
# 13987  headphone popular creation bluetooth method da...        354
# 14355  plantronic headset year late device voyager ed...        252
# 26781  style stereo bluetooth headset soundbot sapphi...        156
# 28487  plantronic backbeat small size portability ear...        247
# 29805  technology day cordless stereo headset conveni...        316
# 33285  product comfortable rel able work great ear so...         95
# 38085  addition update socket month routine use rate ...        128
# 43431  previous version excited new improved version ...        188
# 43500  ultra tone tone weigh weight way ultra heavy h...        523
# 44822  star original review total company customer se...        139
# 45312  complaint seller package unit clear old blueto...        290
# 67636  update month initial thought pro easy sync iph...         97
# 73920  run month happy power button turn unit support...        418
# 74326  good headphone pay bazillion dollar price much...        274
#
#        punctuation  hastags  numerics  upper  word_count
# 7424            21       21         0     86         338
# 13738           26       26         0     32         190
# 13987           31       31         0     49         380
# 14355           29       29         0     31         208
# 26781           27       27         0      3         158
# 28487           22       22         0     55         224
# 29805           40       40         0     25         287
# 33285           42       42         0      5          40
# 38085           28        1         0     24         105
# 43431           28       28         0     23         125
# 43500           28       28         0     87         389
# 44822           84        2         0     16          83
# 45312           25       25         0     38         136
# 67636           60        4         0     16          91
# 73920           36       36         0    124         261
# 74326           28       28         0     38         132

# %%
# check the reviews
df[ df['punctuation'] > 20].reviews.tolist()
# Out:
# ['first time internet product equivalent product product product comfortable good downside downside pain medication ear size part side comfy part purchase',
#  'year good insurance policy cell phone coverage area gps waypoint outside cell coverage hiking shooting rrb time local town cell phone dead spot service max geo search rescue roadside assistance unlimited message year opinion lot money airlift service much year alone figure month important note device smartphone spot device alone unit able message real time potential benefit live earthquake tsunami zone sure cell phone cell phone land line tower tower button survive need help outdoor security afford pro feature useful recording adventure path reference future instance good shooting spot back record spot website topo map map rrb website set page other progress username password people progress log roadside assistance useful vehicle break outdoor cell phone dead spot road service assistance service year geos search rescue search rescue airlift service near hospital case emergency upgrade plan airlift transfer local hospital expensive good near hospital text useful short message people facebook twitter post type short message message contact group website nice need people help gps coordinate safety press smartphone app event emergency roadside assistance smartphone app con bulk big huge live battery use thing battery lithium battery expensive lithium battery camera type local retailer rrb good idea easy replace battery station extra battery connectivity device phone bluetooth app phone iphone use type phone right connectivity issue app unit hope use device time guess issue app update point issue way phone app press button unit great safe mixed service basic service device limited basic service life cost helocopter rescue guessing pocket basic service year many feature roadside assistance geo rescue service opinion device life backpack emergency least geos service cost lot rescue customer service stellar couple time mixed success suspect spot small company limited fund apple quality customer service important issue resolve issue none issue operation unit biggie imho tech new technology satellite time clear area waypoint suspect event emergency transmit perfect solution well unit speed satellite message speed waypoint bicycling speed factor tree overallthis great device peace mind cell phone coverage perfect device option market effective work well satellite available',
#  'new bluetooth headset car opportunity headset music bluetooth device call audio function extra earbud rrb extra ear hook reversible left right ear cable manualsbefore review technical information earset little less half ounce dimension perfect size bluetooth profile hsp hfp noise cancellation range foot baby hour bluetooth device simple headset earset easy use phone voice command text open app great feature connected device battery low love earset lot comfortable headset earset favorite comfortable ear soft plastic nice pivot different angle opposite button multi purpose calling button call device volume rocker port side charge indicator underside mic first call quality various call nokia lumia problem car great clear crisp quality making call house office separate room call call quality excellent music quality device able play music cordless delight box much delight audio spotify app tin thing youtube video cheap headphone store earset music different pro great call comfortable light lot extra earbud call time hour month warranty lifetime technical supportcon music quality good elseoverall call quality great music quality new play music last hour talk time week hour talk time course anker awesome lifetime technical support month warranty testing purpose fair honest',
#  'headphone popular creation bluetooth method datum several manufacturer bluetooth headphone manufacturer headphone headset capable music hand free talking package content male male stereo audio cable instruction manual accessoriesincluded device male male stereo audio cable micro cable thick short inch device micro interface common android cable android user cable standard mobile device external battery several device flat inch male male stereo audio cable gold connector top cord white bottom cord black overall cable specification music time hour talk time hour operating range foot standard support hand free music speaker driver speaker port pin minimum voltage current mah headphone large description page small inch inch open rrb device gray white black red color scheme major color headband minor color headphone cover headphone overall sleek looking headphone casing power multifunctional rrb button micro usb port rrb indicator auxiliary port microphone volume button indicator power rapid blue light power rapid red light blue light second incoming call blue light blue light second mode red light stay red light low battery alarm red light second right headphone casing soundbot logo ear
#  'good headphone pay bazillion dollar price much reasonable nice brand name headphone pay case sound quality great comfort level awesome versatile connect dlx phone ipod wireless worry battery die deal second hassle headphone cable use jack option available time plug work simple fantastic feature rrb record battery dlx sitting battery life hour blast music addition different connection option headphone control phone tablet player work wired connection rrb small drawback nice pause skip music track low raise volume call arm phone ipod microphone base ear pad dlx headset taking call thing last thing overall design little flimsy couple month great flimsy various situation backpack bunch heavy book gym time withstood damage great expand contract nice compact need store mention sturdy carrying case mint condition great pair headphone time nice ear headphone crappy earbud']

# %%
df= df.drop_duplicates(subset=['reviews'])

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80143  B00JFLAEO2-0001       1
# 80144  B00JFLAEO2-0002       1
# 80145  B00JFLAEO2-0003       2
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80100 rows x 9 columns]

# %% [markdown]
# there were 42 duplicates got dropped

# %%
# Lets review the data where punctuation is between 20-100
df[(df['punctuation'] >20) & (df['punctuation'] < 100)]
# Out:
#             product_Id  rating  \
# 7424   B004J96SB8-0025       4
# 13738  B00ENF5CZQ-0006       3
# 13987  B00HWT8I24-0014       3
# 14355  B00JLVNF2O-0024       4
# 26781  B00AVLOHJ8-0936       4
# 28487  B00DIOALPE-0023       0
# 29805  B00IBCRZ3Y-0052       4
# 33285  B001BOEOLK-0001       0
# 38085  B005FPT380-0005       0
# 43431  B00D2CRXKI-0067       2
# 43500  B00D2CRXKI-0136       4
# 44822  B00J5HDEPC-0035       3
# 45312  B0006HTZ80-0211       3
# 67636  B0052YFYFK-0141       3
# 73920  B00DDCHIM0-0001       0
# 74326  B00G6RIF2Q-0002       4
#
#                                                  reviews  stopwords  \
# 7424   year good insurance policy cell phone coverage...        502
# 13738  new bluetooth headset car opportunity headset ...        260
# 13987  headphone popular creation bluetooth method da...        354
# 14355  plantronic headset year late device voyager ed...        252
# 26781  style stereo bluetooth headset soundbot sapphi...        156
# 28487  plantronic backbeat small size portability ear...        247
# 29805  technology day cordless stereo headset conveni...        316
# 33285  product comfortable rel able work great ear so...         95
# 38085  addition update socket month routine use rate ...        128
# 43431  previous version excited new improved version ...        188
# 43500  ultra tone tone weigh weight way ultra heavy h...        523
# 44822  star original review total company customer se...        139
# 45312  complaint seller package unit clear old blueto...        290
# 67636  update month initial thought pro easy sync iph...         97
# 73920  run month happy power button turn unit support...        418
# 74326  good headphone pay bazillion dollar price much...        274
#
#        punctuation  hastags  numerics  upper  word_count
# 7424            21       21         0     86         338
# 13738           26       26         0     32         190
# 13987           31       31         0     49         380
# 14355           29       29         0     31         208
# 26781           27       27         0      3         158
# 28487           22       22         0     55         224
# 29805           40       40         0     25         287
# 33285           42       42         0      5          40
# 38085           28        1         0     24         105
# 43431           28       28         0     23         125
# 43500           28       28         0     87         389
# 44822           84        2         0     16          83
# 45312           25       25         0     38         136
# 67636           60        4         0     16          91
# 73920           36       36         0    124         261
# 74326           28       28         0     38         132

# %%
figure(dpi= 120)
sns.distplot(df.punctuation, rug=True, hist=False, color = 'blue')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='punctuation', ylabel='Density'>

# %% [markdown]
# we have seen that the last two are dulplicates but it didnt got dropped, let drop it.

# %%
df = df[df['punctuation'] < 40]

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80143  B00JFLAEO2-0001       1
# 80144  B00JFLAEO2-0002       1
# 80145  B00JFLAEO2-0003       2
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80095 rows x 9 columns]

# %%
# Plotting the hastags 

df.hastags.value_counts().plot(kind= 'bar')
figure(dpi= 130)

# %%
df[df['hastags'] < 1]
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80141  B00I8QOJBY-0010       4
# 80142  B00JFLAEO2-0000       0
# 80143  B00JFLAEO2-0001       1
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80141  neat device phone car car receiver problem abl...         99
# 80142  feature apt nfc noise cord battery run volume ...        163
# 80143  editin response user ear pad design common noi...        206
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80141            0        0         0     17          47
# 80142            0        0         0     24          91
# 80143            0        0         0     42         182
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [76742 rows x 9 columns]

# %% [markdown]
# Not many hashtags to consider here, we can ignore it for now

# %%
# Plotting the numerics

df.numerics.value_counts().plot(kind= 'bar', color= 'orange')
figure(figsize= (20,10))

# %% [markdown]
# Nothing to be done on numerics

# %%
# Plotting the 'upper' feature
figure(dpi= 120)
sns.kdeplot(df.upper, shade=True, cut=0)
sns.rugplot(df.upper);

# %%
df.loc[df.upper >=200].reviews.tolist()
# Out:
# ['item star awkward earpiece charger rrb love style appearance performance item other tolerate background noise last earpiece lightweight comfortable ear hook necessary gold portable charger real attractive look lipstick container technological device prrformance charger great worry charge home safety bluetooth area man pocket small feminine item product appearance performance fact tech device purse proud piece equipment plantronic removal earpiece external charger',
#  'content promise amend review people background headset plantronic model model couple pro model window cleaner climb roof ladder day fault plantronic headset work rain gutter second dried truck dash hour fine legend day late pro year old speaker well legend love ear pipe audio phone legend thing well time audio direction navigaion phone new phone google map rrb old headset first word audio direction example foot main street legend audio stream quick think fast phone point audio superb complaint rrb plantronic headset people headset work cord way short new connector magnetic careful head door micro headset car rrb cord rrb phone book access rrb work caller announce htc phone shtc android phone grey blue beat audio gsm android new new htc silver factory international version access phone book legend process name running app share htc owner online problem least headset first unit capable trouble people pbap running app headset fault hinge number certain way address book tmobile service number store rrb caller name least case rrb entry legend announce caller couple time idea end update section big problem bad unit rrb headset problem right ear phone pouch workbelt hip back rrb caller fine legend audio phone hold front problem resolve phone test phone hood truck foot phone problem legend poor reception caller voice pocket opposite ear dependent htc phone old sensation sensation contract dual core smartphone good radio old pro headset issue phone workbelt pocket phone kitchen loop flawless audio legend bad useable phone back pocket phone slim bad bluetooth performance metal chasis new tmobile usable back pocket old pro headset audio starting digitize case usuable new phone back pocket least standard rrb unscientific conclusion new phone good antenna amp design cut power output bluetooth weak signal rrb end update section plantronic warranty service replace first picky warranty service company replacement credit card number collateral use box packaging defective unit replacement day way defective headset meantime plantronic credit card number ship replacement first warranty method day bad unit day processing shipping day throw weekend rrb long time buy unavailable time return policy solution amazon replacement return defective unit seller refund fee original shipping return rrb couple hour amazon plantronic email warranty replacement way phone credit card collateral rrb legend day shipping return part one back plantronic dot com amazon pro pro friend test',
#  'good many new bluetooth headset old jabra time clear ear style wear ear warmer hat cold day laundary good thought small month talk least hour night day week talk time great day charge work night ear style wear ear warmer hat cold wind blank little bit end rrb move head wind fine first review half star price great sound great clear end day secure ear bill',
#  'sun door free headset self solid feel last long time easy accesorie power button sec menu audio device accesorie select connect turn mic level max level becuase mic sensative player background noise point ready summary price money good mic great earpiece work life good star comfy head dummy earpiece side headset price noticable feeling head tolorence',
#  'product month work lot device issue good memory device foot product well product fit head son model number good gift battery life good hour single charge sound good con size work large small model big guy neck comfortable jaybird reason witch magnet ear bud neck piece electronic table little pricey par market']

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       0
# 1      B00011FIBO-0001       0
# 2      B00011FIBO-0002       2
# 3      B00011FIBO-0003       2
# 4      B00011FIBO-0004       3
# ...                ...     ...
# 80143  B00JFLAEO2-0001       1
# 80144  B00JFLAEO2-0002       1
# 80145  B00JFLAEO2-0003       2
# 80146  B00JFLAEO2-0004       3
# 80147  B00JFLAEO2-0005       4
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80095 rows x 9 columns]

# %%
# Check the rating graph with the number of reviews
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df['rating'] = df['rating'].apply(lambda x: x + 1)
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3007/2078441892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].apply(lambda x: x + 1)

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       1
# 1      B00011FIBO-0001       1
# 2      B00011FIBO-0002       3
# 3      B00011FIBO-0003       3
# 4      B00011FIBO-0004       4
# ...                ...     ...
# 80143  B00JFLAEO2-0001       2
# 80144  B00JFLAEO2-0002       2
# 80145  B00JFLAEO2-0003       3
# 80146  B00JFLAEO2-0004       4
# 80147  B00JFLAEO2-0005       5
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count
# 0                0        0         0      4          23
# 1                0        0         0      7          21
# 2                0        0         0     14          63
# 3                0        0         0      8          25
# 4                0        0         0      3          13
# ...            ...      ...       ...    ...         ...
# 80143            0        0         0     42         182
# 80144            1        1         0     37         103
# 80145            1        1         0      6          25
# 80146            0        0         0      3           6
# 80147            0        0         0      3          46
#
# [80095 rows x 9 columns]

# %%
df.rating.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %% [markdown]
# Mapped the values 0,1,2,3,4 to 1-5 of ratings. As we can see that most of the reviews has 4/5 ratings as compared to 1/2/3

# %% [markdown]
# lets consider ratings with 4 and 5 as good and 1,2 and 3 as bad review

# %%
df['Review_type']= df.rating
df.Review_type[df.rating <= 3] = 0 #bad review
df.Review_type[df.rating >= 4] = 1 #good review
# Out:
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3007/3456672084.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review_type']= df.rating
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3007/3456672084.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating <= 3] = 0 #bad review
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /var/folders/gk/w9x3t41958b3mryczvgyr0fr0000gn/T/ipykernel_3007/3456672084.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Review_type[df.rating >= 4] = 1 #good review

# %%
df
# Out:
#             product_Id  rating  \
# 0      B00011FIBO-0000       1
# 1      B00011FIBO-0001       1
# 2      B00011FIBO-0002       3
# 3      B00011FIBO-0003       3
# 4      B00011FIBO-0004       4
# ...                ...     ...
# 80143  B00JFLAEO2-0001       2
# 80144  B00JFLAEO2-0002       2
# 80145  B00JFLAEO2-0003       3
# 80146  B00JFLAEO2-0004       4
# 80147  B00JFLAEO2-0005       5
#
#                                                  reviews  stopwords  \
# 0      headset circuit city last trip actiontec site ...         29
# 1      bluetooth headset comment actiontec website mu...         56
# 2      lightweight tiny sound quality person well pho...        100
# 3      work phone able pair phone fine bluetooth voic...         64
# 4      item work setup headset phone sound quality gr...         32
# ...                                                  ...        ...
# 80143  editin response user ear pad design common noi...        206
# 80144  previous low price bluetooth version costco aw...         77
# 80145  sound fine next massive construction site apar...         64
# 80146           work complaint come case different brand         15
# 80147  great headphone reason whole ear top effective...         82
#
#        punctuation  hastags  numerics  upper  word_count  Review_type
# 0                0        0         0      4          23            0
# 1                0        0         0      7          21            0
# 2                0        0         0     14          63            0
# 3                0        0         0      8          25            0
# 4                0        0         0      3          13            1
# ...            ...      ...       ...    ...         ...          ...
# 80143            0        0         0     42         182            0
# 80144            1        1         0     37         103            0
# 80145            1        1         0      6          25            0
# 80146            0        0         0      3           6            1
# 80147            0        0         0      3          46            1
#
# [80095 rows x 10 columns]

# %%
df.Review_type.value_counts().plot(kind= 'bar', color= 'blue')
figure(figsize= (20,10))

# %%
df.to_csv('bluetooth_after_data_exploration.csv', index=False)
