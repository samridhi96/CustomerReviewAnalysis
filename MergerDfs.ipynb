# %%
import pandas as pd
import numpy as np

# %%
bags_and_cases = pd.read_csv('./DataExploration/bags_and_cases_after_data_exploration.csv')

# %%
bags_and_cases = pd.read_csv('./DataExploration/bags_and_cases_after_data_exploration.csv')
keyboards = pd.read_csv('./DataExploration/keyboards_after_data_exploration.csv')
bluetooth = pd.read_csv('./DataExploration/bluetooth_after_data_exploration.csv')
boots = pd.read_csv('./DataExploration/boots_after_data_exploration.csv')
tv = pd.read_csv('./DataExploration/tv_after_data_exploration.csv')
vacuums = pd.read_csv('./DataExploration/vacuums_after_data_exploration.csv')

# %%
bags_and_cases['product_type'] = 'bags_and_cases'
keyboards['product_type'] = 'keyboards'
bluetooth['product_type'] = 'bluetooth'
boots['product_type'] = 'boots'
tv['product_type'] = 'tv'
vacuums['product_type'] = 'vacuums'

# %%
merged_df = pd.concat([bags_and_cases, keyboards, bluetooth, boots, tv, vacuums ])

# %%
merged_df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       3
# 1      B00001OPGT-0001       4
# 2      B00001OPGT-0002       4
# 3      B00001OPGT-0003       5
# 4      B00001OPGT-0004       5
# ...                ...     ...
# 68122  B00J5UD0FI-0000       3
# 68123  B00J5UD0FI-0001       4
# 68124  B00J5UD0FI-0002       4
# 68125  B00J5UD0FI-0003       5
# 68126  B00J5UD0FI-0004       5
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 68122  good machine decent quality good job corner ha...         19
# ...

# %%
merged_df[merged_df['product_type'] == 'keyboards']
# Out:
#             product_Id  rating  \
# 0      B00000J1UG-0000       3
# 1      B00000J1UG-0001       4
# 2      B00000J1UG-0002       4
# 3      B00000J1UG-0003       5
# 4      B00000J1UG-0004       5
# ...                ...     ...
# 33588  BT008UKTMW-0004       4
# 33589  BT008UKTMW-0005       4
# 33590  BT008UKTMW-0006       4
# 33591  BT008UKTMW-0007       5
# 33592  BT008UKTMW-0008       5
#
#                                                  reviews  stopwords  \
# 0      keyboard store discoverd ergonomic flat curve ...         33
# 1      keyboard random inexpensive due issue great co...         68
# 2      old key ergo keyboard belkin keyboard similar ...        203
# 3      keyboard key correct side split touch great re...         19
# 4      black office white home comfortable key proper...         30
# ...                                                  ...        ...
# 33588  great little device price other market keyboar...         24
# ...

# %%
merged_df.drop_duplicates()
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       3
# 1      B00001OPGT-0001       4
# 2      B00001OPGT-0002       4
# 3      B00001OPGT-0003       5
# 4      B00001OPGT-0004       5
# ...                ...     ...
# 68122  B00J5UD0FI-0000       3
# 68123  B00J5UD0FI-0001       4
# 68124  B00J5UD0FI-0002       4
# 68125  B00J5UD0FI-0003       5
# 68126  B00J5UD0FI-0004       5
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 68122  good machine decent quality good job corner ha...         19
# ...

# %%
merged_df = merged_df.dropna()

# %%
merged_df
# Out:
#             product_Id  rating  \
# 0      B00001OPGT-0000       3
# 1      B00001OPGT-0001       4
# 2      B00001OPGT-0002       4
# 3      B00001OPGT-0003       5
# 4      B00001OPGT-0004       5
# ...                ...     ...
# 68122  B00J5UD0FI-0000       3
# 68123  B00J5UD0FI-0001       4
# 68124  B00J5UD0FI-0002       4
# 68125  B00J5UD0FI-0003       5
# 68126  B00J5UD0FI-0004       5
#
#                                                  reviews  stopwords  \
# 0      case nice plenty pocket stuff office thin lapt...         76
# 1      month toshiba laptop case strong thou side bag...         44
# 2      pic product justice real thing good black synt...         26
# 3      pavilion rrb thing laptop front pocket fit pow...         38
# 4      happy bag expectation satellite adjustable pad...         32
# ...                                                  ...        ...
# 68122  good machine decent quality good job corner ha...         19
# ...

# %%
set(merged_df['product_type'])
# Out:
# {'bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums'}

# %%
merged_df.to_csv('merged_df.csv', index=False)
